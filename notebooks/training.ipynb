# %% [markdown]
# ## Building Reinforcement Learning Model

# %%
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
import os
from stable_baselines3 import PPO # load PPO (Proximal Policy Optimization) Algorithm
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.results_plotter import load_results, ts2xy, plot_results
import numpy as np
# Out:
# WARNING:tensorflow:From c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env,SIMPLE_MOVEMENT)
# GrayScale the environment
env = GrayScaleObservation(env,keep_dim=True)
# Wrap inside a DummyVecEnv to support vectorized environments
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env,n_stack=4, channels_order="last")

# %% [markdown]
# - `class TrainingAndLoggingCallBack` is used to log the training process & save the model each k steps defined

# %%
class TrainingAndLoggingCallback(BaseCallback):
    
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainingAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
    
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            self.model.save(self.save_path + f"/new_model_{self.n_calls}")
        return True

# %%
CHECKPOINT_DIR = "../train/"
LOG_DIR = "../tensorboard_logs/"

# %%
# setups the callback function to save the model every 500000 steps
callback = TrainingAndLoggingCallback(check_freq=100000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ### Creating the PPO model

# %% [markdown]
# - Cnn Policy is a convolutional neural network policy that was designed for images as input

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.0000003, n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# ### Training the model

# %%
# Train the agent for 5M steps meaning 5M frames the model will be trained on
model.learn(total_timesteps=5000000, callback=callback)
# Out:
# Logging to ./tensorboard_logs/PPO_1
# c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# -----------------------------
# | time/              |      |
# |    fps             | 192  |
# |    iterations      | 1    |
# |    time_elapsed    | 10   |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 121          |
# |    iterations           | 2            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.265364e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00115      |
# |    learning_rate        | 3e-07        |
# |    loss                 | 37           |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00011     |
# |    value_loss           | 117          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 108          |
# |    iterations           | 3            |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 9.284879e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00364      |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.157        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000116    |
# |    value_loss           | 0.325        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 103           |
# |    iterations           | 4             |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 5.5937853e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00223      |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.183         |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000102     |
# |    value_loss           | 0.317         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 5            |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 3.017194e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0271       |
# |    learning_rate        | 3e-07        |
# |    loss                 | 55           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -1.61e-06    |
# |    value_loss           | 88.8         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 6             |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.2402015e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00567       |
# |    learning_rate        | 3e-07         |
# |    loss                 | 10.8          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -4.09e-05     |
# |    value_loss           | 56.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 98            |
# |    iterations           | 7             |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.8801133e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0395        |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.459         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000262     |
# |    value_loss           | 0.928         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 8             |
# |    time_elapsed         | 167           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.1546712e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00583      |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.126         |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000167     |
# |    value_loss           | 0.41          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 98            |
# |    iterations           | 9             |
# |    time_elapsed         | 187           |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 4.8807415e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0527        |
# |    learning_rate        | 3e-07         |
# |    loss                 | 55.5          |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -3.23e-05     |
# |    value_loss           | 139           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 98            |
# |    iterations           | 10            |
# |    time_elapsed         | 208           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 3.4203695e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.269         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.119         |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000381     |
# |    value_loss           | 0.428         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 97           |
# |    iterations           | 11           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 8.107355e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0423       |
# |    learning_rate        | 3e-07        |
# |    loss                 | 121          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.000124     |
# |    value_loss           | 234          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 12            |
# |    time_elapsed         | 252           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 2.5864021e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.029        |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.17          |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000164     |
# |    value_loss           | 0.86          |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 97             |
# |    iterations           | 13             |
# |    time_elapsed         | 273            |
# |    total_timesteps      | 26624          |
# | train/                  |                |
# |    approx_kl            | 1.29469845e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | -0.00176       |
# |    learning_rate        | 3e-07          |
# |    loss                 | 0.0726         |
# |    n_updates            | 120            |
# |    policy_gradient_loss | -6.9e-05       |
# |    value_loss           | 0.415          |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 97           |
# |    iterations           | 14           |
# |    time_elapsed         | 294          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 4.348927e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00676     |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.0654       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -1.31e-05    |
# |    value_loss           | 0.294        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 15            |
# |    time_elapsed         | 314           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 3.4551136e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.134         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 76.9          |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -9.1e-05      |
# |    value_loss           | 156           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 16            |
# |    time_elapsed         | 335           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.4593534e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0785        |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.195         |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -7.41e-05     |
# |    value_loss           | 0.758         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 17            |
# |    time_elapsed         | 357           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 3.2097043e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.744         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.176         |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000251     |
# |    value_loss           | 0.463         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 97           |
# |    iterations           | 18           |
# |    time_elapsed         | 379          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 8.657837e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00102     |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.118        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -5.41e-05    |
# |    value_loss           | 0.31         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 19            |
# |    time_elapsed         | 401           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 1.8011633e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.2           |
# |    learning_rate        | 3e-07         |
# |    loss                 | 60.8          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 1.79e-05      |
# |    value_loss           | 102           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 20            |
# |    time_elapsed         | 424           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.1203636e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.199         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.089         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -3.08e-05     |
# |    value_loss           | 0.649         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 21           |
# |    time_elapsed         | 448          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 3.462183e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.222        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00028     |
# |    value_loss           | 0.543        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 22           |
# |    time_elapsed         | 469          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 3.327697e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0105      |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.098        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000229    |
# |    value_loss           | 0.247        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 23            |
# |    time_elapsed         | 489           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 3.0214724e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.186         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 101           |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000204     |
# |    value_loss           | 145           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 24            |
# |    time_elapsed         | 510           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 2.6006077e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.459         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0923        |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000121     |
# |    value_loss           | 0.498         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 25           |
# |    time_elapsed         | 530          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 4.157779e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.0803       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000314    |
# |    value_loss           | 0.323        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 26            |
# |    time_elapsed         | 551           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 1.6477454e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0146       |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0782        |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -7.26e-05     |
# |    value_loss           | 0.151         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 27            |
# |    time_elapsed         | 572           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 2.6641967e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.237         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 38.4          |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -7.18e-06     |
# |    value_loss           | 117           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 28           |
# |    time_elapsed         | 593          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 3.600365e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.0738       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000175    |
# |    value_loss           | 0.476        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 29            |
# |    time_elapsed         | 615           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 3.4469092e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.526         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0814        |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00025      |
# |    value_loss           | 0.33          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 30           |
# |    time_elapsed         | 638          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 4.847467e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.109        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00037     |
# |    value_loss           | 0.255        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 31            |
# |    time_elapsed         | 661           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 6.6661305e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.247         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 66.3          |
# |    n_updates            | 300           |
# |    policy_gradient_loss | 6.17e-05      |
# |    value_loss           | 117           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 95            |
# |    iterations           | 32            |
# |    time_elapsed         | 684           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 1.5256781e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.245         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.18          |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -3.97e-05     |
# |    value_loss           | 0.638         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 33           |
# |    time_elapsed         | 705          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 6.129034e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.22         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 1.59e-05     |
# |    value_loss           | 0.468        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 34           |
# |    time_elapsed         | 726          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 4.799114e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0102      |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.0842       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000272    |
# |    value_loss           | 0.203        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 95            |
# |    iterations           | 35            |
# |    time_elapsed         | 748           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 6.3447515e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.144         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 97.7          |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 1.09e-05      |
# |    value_loss           | 155           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 95            |
# |    iterations           | 36            |
# |    time_elapsed         | 771           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 4.2060856e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.17          |
# |    learning_rate        | 3e-07         |
# |    loss                 | 2.96          |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 1.4e-05       |
# |    value_loss           | 2.57          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 95           |
# |    iterations           | 37           |
# |    time_elapsed         | 791          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 6.668386e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.152        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.135        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000373    |
# |    value_loss           | 0.336        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 38           |
# |    time_elapsed         | 809          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 5.514003e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.401        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.118        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000358    |
# |    value_loss           | 0.219        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 96            |
# |    iterations           | 39            |
# |    time_elapsed         | 827           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 5.5897515e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.161         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 94.7          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000134     |
# |    value_loss           | 170           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 96           |
# |    iterations           | 40           |
# |    time_elapsed         | 845          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 4.311488e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.0574       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000165    |
# |    value_loss           | 0.255        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 41            |
# |    time_elapsed         | 862           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 1.0123826e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.35          |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0752        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -3.36e-05     |
# |    value_loss           | 0.226         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 97            |
# |    iterations           | 42            |
# |    time_elapsed         | 880           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 2.9712915e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.905         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0774        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000171     |
# |    value_loss           | 0.202         |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 97             |
# |    iterations           | 43             |
# |    time_elapsed         | 898            |
# |    total_timesteps      | 88064          |
# | train/                  |                |
# |    approx_kl            | 0.000106464606 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.93          |
# |    explained_variance   | 0.27           |
# |    learning_rate        | 3e-07          |
# |    loss                 | 78.1           |
# |    n_updates            | 420            |
# |    policy_gradient_loss | 3.6e-05        |
# |    value_loss           | 140            |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 98            |
# |    iterations           | 44            |
# |    time_elapsed         | 916           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 3.7738995e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.221         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.146         |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000116     |
# |    value_loss           | 0.554         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 98            |
# |    iterations           | 45            |
# |    time_elapsed         | 934           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.8726016e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.366         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.142         |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -7.88e-05     |
# |    value_loss           | 0.39          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 98            |
# |    iterations           | 46            |
# |    time_elapsed         | 952           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 3.9819744e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.893         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.123         |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000172     |
# |    value_loss           | 0.221         |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 99             |
# |    iterations           | 47             |
# |    time_elapsed         | 969            |
# |    total_timesteps      | 96256          |
# | train/                  |                |
# |    approx_kl            | 0.000119363685 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.92          |
# |    explained_variance   | 0.265          |
# |    learning_rate        | 3e-07          |
# |    loss                 | 40.4           |
# |    n_updates            | 460            |
# |    policy_gradient_loss | 0.000167       |
# |    value_loss           | 137            |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 48            |
# |    time_elapsed         | 987           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.2364326e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.101         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0627        |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -3.94e-06     |
# |    value_loss           | 0.367         |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 49          |
# |    time_elapsed         | 1006        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 6.34772e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 3e-07       |
# |    loss                 | 0.062       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.000333   |
# |    value_loss           | 0.323       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 99            |
# |    iterations           | 50            |
# |    time_elapsed         | 1025          |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 1.7116428e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.603         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0538        |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -4.88e-05     |
# |    value_loss           | 0.264         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 51            |
# |    time_elapsed         | 1044          |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00010499242 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.274         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 20.1          |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 6.57e-05      |
# |    value_loss           | 110           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 52            |
# |    time_elapsed         | 1062          |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 1.7839775e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.327         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.107         |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -5.21e-05     |
# |    value_loss           | 0.421         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 53            |
# |    time_elapsed         | 1080          |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 3.2690965e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.649         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.103         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000162     |
# |    value_loss           | 0.324         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 54            |
# |    time_elapsed         | 1098          |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 1.6402919e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.0228        |
# |    learning_rate        | 3e-07         |
# |    loss                 | 6.22          |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -4.55e-05     |
# |    value_loss           | 23.5          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 55            |
# |    time_elapsed         | 1117          |
# |    total_timesteps      | 112640        |
# | train/                  |               |
# |    approx_kl            | 0.00012843256 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.253         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 48.8          |
# |    n_updates            | 540           |
# |    policy_gradient_loss | 2.45e-05      |
# |    value_loss           | 119           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 56            |
# |    time_elapsed         | 1135          |
# |    total_timesteps      | 114688        |
# | train/                  |               |
# |    approx_kl            | 6.7278685e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.248         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0766        |
# |    n_updates            | 550           |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 0.395         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 57           |
# |    time_elapsed         | 1152         |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 7.215669e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.226        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 0.0436       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000209    |
# |    value_loss           | 0.282        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 58            |
# |    time_elapsed         | 1170          |
# |    total_timesteps      | 118784        |
# | train/                  |               |
# |    approx_kl            | 1.1124386e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.143         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.134         |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -3.52e-05     |
# |    value_loss           | 4.3           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 101          |
# |    iterations           | 59           |
# |    time_elapsed         | 1188         |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 8.838659e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.262        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 34.4         |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 2.88e-05     |
# |    value_loss           | 95.9         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 101           |
# |    iterations           | 60            |
# |    time_elapsed         | 1206          |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 8.4329135e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.9          |
# |    explained_variance   | 0.317         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 0.0546        |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000313     |
# |    value_loss           | 0.277         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 102          |
# |    iterations           | 61           |
# |    time_elapsed         | 1224         |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0002085453 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.291        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 50           |
# |    n_updates            | 600          |
# |    policy_gradient_loss | 0.000189     |
# |    value_loss           | 158          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 62            |
# |    time_elapsed         | 1242          |
# |    total_timesteps      | 126976        |
# | train/                  |               |
# ...
# |    loss                 | 432          |
# |    n_updates            | 24050        |
# |    policy_gradient_loss | -0.000124    |
# |    value_loss           | 523          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 2407          |
# |    time_elapsed         | 49042         |
# |    total_timesteps      | 4929536       |
# | train/                  |               |
# |    approx_kl            | 0.00048800127 |
# |    clip_fraction        | 0.000537      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.443        |
# |    explained_variance   | 0.858         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 137           |
# |    n_updates            | 24060         |
# |    policy_gradient_loss | 0.000254      |
# |    value_loss           | 331           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 2408         |
# |    time_elapsed         | 49063        |
# |    total_timesteps      | 4931584      |
# | train/                  |              |
# |    approx_kl            | 0.0005277914 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 279          |
# |    n_updates            | 24070        |
# |    policy_gradient_loss | -0.000804    |
# |    value_loss           | 570          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 2409         |
# |    time_elapsed         | 49086        |
# |    total_timesteps      | 4933632      |
# | train/                  |              |
# |    approx_kl            | 0.0008573625 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.445       |
# |    explained_variance   | 0.775        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 376          |
# |    n_updates            | 24080        |
# |    policy_gradient_loss | -0.000476    |
# |    value_loss           | 573          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 2410         |
# |    time_elapsed         | 49109        |
# |    total_timesteps      | 4935680      |
# | train/                  |              |
# |    approx_kl            | 0.0003133915 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.471       |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 228          |
# |    n_updates            | 24090        |
# |    policy_gradient_loss | -0.000569    |
# |    value_loss           | 440          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 2411          |
# |    time_elapsed         | 49131         |
# |    total_timesteps      | 4937728       |
# | train/                  |               |
# |    approx_kl            | 3.7425634e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.433        |
# |    explained_variance   | 0.797         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 489           |
# |    n_updates            | 24100         |
# |    policy_gradient_loss | 0.000114      |
# |    value_loss           | 468           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 2412          |
# |    time_elapsed         | 49153         |
# |    total_timesteps      | 4939776       |
# | train/                  |               |
# |    approx_kl            | 0.00040692437 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.441        |
# |    explained_variance   | 0.825         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 452           |
# |    n_updates            | 24110         |
# |    policy_gradient_loss | -0.000408     |
# |    value_loss           | 348           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 2413          |
# |    time_elapsed         | 49175         |
# |    total_timesteps      | 4941824       |
# | train/                  |               |
# |    approx_kl            | 0.00037941322 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.425        |
# |    explained_variance   | 0.755         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 223           |
# |    n_updates            | 24120         |
# |    policy_gradient_loss | 0.000358      |
# |    value_loss           | 439           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 2414         |
# |    time_elapsed         | 49196        |
# |    total_timesteps      | 4943872      |
# | train/                  |              |
# |    approx_kl            | 0.0011274428 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.402       |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 209          |
# |    n_updates            | 24130        |
# |    policy_gradient_loss | -0.00013     |
# |    value_loss           | 383          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 2415         |
# |    time_elapsed         | 49218        |
# |    total_timesteps      | 4945920      |
# | train/                  |              |
# |    approx_kl            | 0.0010091921 |
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.391       |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 3e-07        |
# |    loss                 | 252          |
# |    n_updates            | 24140        |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 443          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 100         |
# |    iterations           | 2416        |
# |    time_elapsed         | 49240       |
# |    total_timesteps      | 4947968     |
# | train/                  |             |
# |    approx_kl            | 0.002011757 |
# |    clip_fraction        | 0.0083      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.395      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 3e-07       |
# |    loss                 | 285         |
# |    n_updates            | 24150       |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 430         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 100           |
# |    iterations           | 2417          |
# |    time_elapsed         | 49262         |
# |    total_timesteps      | 4950016       |
# | train/                  |               |
# |    approx_kl            | 0.00010964932 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.395        |
# |    explained_variance   | 0.802         |
# |    learning_rate        | 3e-07         |
# |    loss                 | 304           |
# |    n_updates            | 24160         |
# |    policy_gradient_loss | -6.85e-05     |
# |    value_loss           | 447           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 100          |
# |    iterations           | 2418         |
# |    time_elapsed         | 49284        |
# |    total_timesteps      | 4952064      |
# | train/                  |              |
# |    approx_kl            | 0.0007069971 |
# |    clip_fraction        | 0.000879     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.393       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 3e-07        |
# |    loss                 | 144          |
# |    n_updates            | 24170        |
# |    policy_gradient_loss | -0.000334    |
# |    value_loss           | 414          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Train the agent for 5M steps meaning 10M frames the model will be trained on
# ----> 2 model.learn(total_timesteps=5000000, callback=callback)
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\ppo\ppo.py:307, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 def learn(
#     298     self: SelfPPO,
#     299     total_timesteps: int,
#    (...)
#     304     progress_bar: bool = False,
#     305 ) -> SelfPPO:
# --> 307     return super().learn(
#     308         total_timesteps=total_timesteps,
#     309         callback=callback,
#     310         log_interval=log_interval,
#     311         tb_log_name=tb_log_name,
#     312         reset_num_timesteps=reset_num_timesteps,
#     313         progress_bar=progress_bar,
#     314     )
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:248, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     244 callback.on_training_start(locals(), globals())
#     246 while self.num_timesteps < total_timesteps:
# --> 248     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     250     if continue_training is False:
#     251         break
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:175, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     172 if isinstance(self.action_space, spaces.Box):
#     173     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 175 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     177 self.num_timesteps += env.num_envs
#     179 # Give access to local variables
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:163, in VecEnv.step(self, actions)
#     156 """
#     157 Step the environments with the given action
#     158
#     159 :param actions: the action
#     160 :return: observation, reward, done, information
#     161 """
#     162 self.step_async(actions)
# --> 163 return self.step_wait()
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py:95, in VecTransposeImage.step_wait(self)
#      94 def step_wait(self) -> VecEnvStepReturn:
# ---> 95     observations, rewards, dones, infos = self.venv.step_wait()
#      97     # Transpose the terminal observations
#      98     for idx, done in enumerate(dones):
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py:48, in VecFrameStack.step_wait(self)
#      44 def step_wait(
#      45     self,
#      46 ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
# ---> 48     observations, rewards, dones, infos = self.venv.step_wait()
#      50     observations, infos = self.stackedobs.update(observations, dones, infos)
#      52     return observations, rewards, dones, infos
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:54, in DummyVecEnv.step_wait(self)
#      52 def step_wait(self) -> VecEnvStepReturn:
#      53     for env_idx in range(self.num_envs):
# ---> 54         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      55             self.actions[env_idx]
#      56         )
#      57         if self.buf_dones[env_idx]:
#      58             # save final observation where user can get it, then reset
#      59             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\core.py:323, in ObservationWrapper.step(self, action)
#     322 def step(self, action):
# --> 323     observation, reward, done, info = self.env.step(action)
#     324     return self.observation(observation), reward, done, info
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\nes_py\wrappers\joypad_space.py:74, in JoypadSpace.step(self, action)
#      59 """
#      60 Take a step using the given action.
#      61
#    (...)
#      71
#      72 """
#      73 # take the step and record the output
# ---> 74 return self.env.step(self._action_map[action])
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\wrappers\time_limit.py:18, in TimeLimit.step(self, action)
#      14 def step(self, action):
#      15     assert (
#      16         self._elapsed_steps is not None
#      17     ), "Cannot call env.step() before calling reset()"
# ---> 18     observation, reward, done, info = self.env.step(action)
#      19     self._elapsed_steps += 1
#      20     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\nes_py\nes_env.py:308, in NESEnv.step(self, action)
#     306 info = self._get_info()
#     307 # call the after step callback
# --> 308 self._did_step(self.done)
#     309 # bound the reward in [min, max]
#     310 if reward < self.reward_range[0]:
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym_super_mario_bros\smb_env.py:391, in SuperMarioBrosEnv._did_step(self, done)
#     388 self._skip_change_area()
#     389 # skip occupied states like the black screen between lives that shows
#     390 # how many lives the player has left
# --> 391 self._skip_occupied_states()
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym_super_mario_bros\smb_env.py:278, in SuperMarioBrosEnv._skip_occupied_states(self)
#     276 while self._is_busy or self._is_world_over:
#     277     self._runout_prelevel_timer()
# --> 278     self._frame_advance(0)
#
# File c:\Users\ahmed\AppData\Local\Programs\Python\Python311\Lib\site-packages\nes_py\nes_env.py:211, in NESEnv._frame_advance(self, action)
#     209 self.controllers[0][:] = action
#     210 # perform a step on the emulator
# --> 211 _LIB.Step(self._env)
#
# KeyboardInterrupt:
